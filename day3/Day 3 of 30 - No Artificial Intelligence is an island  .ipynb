# %% [markdown]
# # Day 3/30 - No “Artificial Intelligence” is an island
# #### Manual vs Tool-based MSE Calculation
# This notebook is part of my public #30DaysOfLearning journey.
#
# This code demonstrates how to calculate the Mean Squared Error (MSE), a key cost function in Linear Regression, using two approaches: manual calculation using my function and Scikit-learn’s built-in function.
#
# The goal is to make abstract theory in machine learning more tangible by building small, practical projects.
#
# ## Python Code

# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Create sample data

# Features (independent variable) - e.g., study hours
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)

# Target values (dependent variable) - e.g., test scores
y = np.array([2, 3, 4, 4, 5])

# %%
# Create and train the model
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = regression.predict(X)

# %%
# Calculate MSE manually - part 1
mse_manual_1 = (1/y_pred.size) * sum((y_pred - y) ** 2)

# Calculate MSE manually - part 2
mse_manual_2 = np.average((y_pred - y)**2, axis = 0)

# Calculate MSE using scikit-learn
mse_sklearn = mean_squared_error(y, y_pred)

# %% [markdown]
# ## Display results

# %%
print("📊 First Manual MSE:", mse_manual_1)
print("📊 Second Manual MSE:", mse_manual_2)
print("🤖 Scikit-learn MSE:", mse_sklearn)

# Let's see if they're all the same!
if np.isclose(mse_manual_1, mse_manual_2) and np.isclose(mse_manual_1, mse_sklearn):
    print("🎉 All three methods give the same result! Consistency for the win!")
else:
    print("🧐 Hmm... Something's off. The MSE values don't quite match.")
# Out:
# 📊 First Manual MSE: 0.06000000000000007
# 📊 Second Manual MSE: 0.06000000000000007
# 🤖 Scikit-learn MSE: 0.06000000000000007
# 🎉 All three methods give the same result! Consistency for the win!

# %% [markdown]
# ## Plot the data and prediction line

# %%
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Prediction line')
plt.title('Linear Regression Model')
plt.xlabel('X (Feature)')
plt.ylabel('y (Target)')
plt.legend()
plt.grid()
plt.show()
